# %%
pwd
# Out:
# 'C:\\Users\\io\\Desktop'

# %%
import pandas as pd

# %%
df = pd.read_csv("train.csv")

# %%
print(df.shape)
print(df.count())
# Out:
# (891, 12)
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(18,6))

# %%
plt.subplot2grid((2,3),(0,0))
df.Survived.value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title("survived")
# Out:
# Text(0.5, 1.0, 'survived')

# %%
plt.subplot2grid((2,3),(0,1))
plt.scatter(df.Survived, df.Age, alpha=0.1)
plt.title("age with survived")
# Out:
# Text(0.5, 1.0, 'age with survived')

# %%
plt.subplot2grid((2,3),(0,2))
df.Pclass.value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title("Class")
# Out:
# Text(0.5, 1.0, 'Class')

# %%
plt.subplot2grid((2,3),(1,0),colspan=2)
for x in [1,2,3]:
    df.Age[df.Pclass == x].plot(kind='kde')
plt.title("class with age")
plt.legend(("list","2nd","3rd"))

# %%
plt.subplot2grid((2,3),(1,2))
df.Embarked.value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title("Embarked")
# Out:
# Text(0.5, 1.0, 'Embarked')

# %%
#GENDER
female_col = "#FA0000"
df = pd.read_csv("train.csv")
fig = plt.figure(figsize=(18,6))
plt.subplot2grid((2,3),(0,0))
df.Survived.value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title("survived")

plt.subplot2grid((2,3),(0,1))
df.Survived[df.Sex == "male"].value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title(" men survived")

plt.subplot2grid((2,3),(0,2))
df.Survived[df.Sex == "female"].value_counts(normalize=True).plot(kind='bar',alpha=0.5,color=female_col)
plt.title(" women survived")

plt.subplot2grid((3,4),(1,0),colspan=4)
for x in [1,2,3]:
    df.Survived[df.Pclass == x].plot(kind='kde')
plt.title("class wrt survived")
plt.legend(("list","2nd","3rd"))

plt.subplot2grid((3,4),(2,0))
df.Survived[(df.Sex == "male") & (df.Pclass ==1)].value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title(" rich men survived")

plt.subplot2grid((3,4),(2,1))
df.Survived[(df.Sex == "male") & (df.Pclass ==3)].value_counts(normalize=True).plot(kind='bar',alpha=0.5)
plt.title(" poor  men survived")

plt.subplot2grid((3,4),(2,2))
df.Survived[(df.Sex == "female") & (df.Pclass ==1)].value_counts(normalize=True).plot(kind='bar',alpha=0.5,color=female_col)
plt.title(" rich women survived")

plt.subplot2grid((3,4),(2,3))
df.Survived[(df.Sex == "female") & (df.Pclass ==3)].value_counts(normalize=True).plot(kind='bar',alpha=0.5,color=female_col)
plt.title(" poor  women survived")
# Out:
# Text(0.5, 1.0, ' poor  women survived')
