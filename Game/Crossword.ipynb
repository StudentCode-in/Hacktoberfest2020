# %%
#Guessing Game

# %%
import random

name = input("Enter your name: ")
print(f"Hello {name}! Welcome to the guessing game!")
words = ["Laptop","apple","earphones","Algorithm","python",
        "television", "sunset","opensource"]
# get a random word from this list
index = random.randint(0, len(words))
word = words[index]
indexes = random.sample(range(0, len(word)), 3) #generate random chr to display
guesses = "" #characters that the user has guessed so far
for i in indexes:
    guesses += word[i]
chances = 10
play = "Yes"

def playagain():
    # this will help you understad scoping
    global play
    play = input("Do you want to play again? (Yes/No): ")
    if play == "Yes":
        global chances, word, guesses
        chances = 10
        index = random.randint(0, len(words))
        word = words[index]
        indexes = random.sample(range(0, len(word)), 3)
        guesses = "" 
        for i in indexes:
            guesses += word[i]

# this play is global variable
while play == "Yes":
    while chances > 0:
        won = True
        for ch in word:
            if ch in guesses: # the person has guessed
                print(ch, end=" ")
            else:
                print("_", end=" ")
                won = False

        if won:
            print("\nYou Won!")
            print(f"Your score is {chances * 10}")
            playagain()
            break

        # take a guess from the user
        guess = input("\nGuess a character: ")
        guesses += guess

        if guess not in word:
            chances -= 1
            print("\nWrong Answer!!")
            print(f"You have {chances} chances left!")

            if chances == 0:
                print("You Lose!!")
                playagain()
                break

print("Thanks for playing!")
# Out:
# Enter your name: Akanksha
# Hello Akanksha! Welcome to the guessing game!
# o _ _ _ _ o _ _ c _
# Guess a character: s
# o _ _ _ s o _ _ c _
# Guess a character: e
# o _ e _ s o _ _ c e
# Guess a character: n
# o _ e n s o _ _ c e
# Guess a character: p
# o p e n s o _ _ c e
# Guess a character: r
# o p e n s o _ r c e
# Guess a character: u
# o p e n s o u r c e
# You Won!
# Your score is 100
# Do you want to play again? (Yes/No): Yes
# s _ _ s e t
# Guess a character: w
#
# Wrong Answer!!
# You have 9 chances left!
# s _ _ s e t
# Guess a character: q
#
# Wrong Answer!!
# You have 8 chances left!
# s _ _ s e t
# Guess a character: e
# s _ _ s e t
# Guess a character: u
# s u _ s e t
# Guess a character: n
# s u n s e t
# You Won!
# Your score is 80
# Do you want to play again? (Yes/No): Yes
# o _ e n _ o _ _ _ e
# Guess a character: s
# o _ e n s o _ _ _ e
# Guess a character: f
#
# Wrong Answer!!
# You have 9 chances left!
# o _ e n s o _ _ _ e
# Guess a character: v
#
# Wrong Answer!!
# You have 8 chances left!
# o _ e n s o _ _ _ e
# Guess a character: d
#
# Wrong Answer!!
# You have 7 chances left!
# o _ e n s o _ _ _ e
# Guess a character: s
# o _ e n s o _ _ _ e
# Guess a character: r
# o _ e n s o _ r _ e
# Guess a character: e
# o _ e n s o _ r _ e
# Guess a character: s
# o _ e n s o _ r _ e
# Guess a character: a
#
# Wrong Answer!!
# You have 6 chances left!
# o _ e n s o _ r _ e
# Guess a character: g
#
# Wrong Answer!!
# You have 5 chances left!
# o _ e n s o _ r _ e
# Guess a character: k
#
# Wrong Answer!!
# You have 4 chances left!
# o _ e n s o _ r _ e
# Guess a character: i
#
# Wrong Answer!!
# You have 3 chances left!
# o _ e n s o _ r _ e
# Guess a character: l
#
# Wrong Answer!!
# You have 2 chances left!
# o _ e n s o _ r _ e
# Guess a character: l
#
# Wrong Answer!!
# You have 1 chances left!
# o _ e n s o _ r _ e
# Guess a character: l
#
# Wrong Answer!!
# You have 0 chances left!
# You Lose!!
# Do you want to play again? (Yes/No): Yes
# a p p _ e
# Guess a character: l
# a p p l e
# You Won!
# Your score is 100
# Do you want to play again? (Yes/No): no
# Thanks for playing!
